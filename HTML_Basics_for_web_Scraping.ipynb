# %% [markdown]
# <a href="https://colab.research.google.com/github/makbd71/Pyhton_learning/blob/main/HTML_Basics_for_web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import display, HTML

html_code = """
<h1>HTML Basics for web Scraping</h1>

<ul>
    <li> Importance of understanding HTML</li>
    <li> Beackbone of webpages </li>
    <li> Essential skill for data engineering</li>
</ul>
"""

display(HTML(html_code))
# Out:
# <h1>HTML Basics for web Scraping</h1>
#
# <ul>
#     <li> Importance of understanding HTML</li>
#     <li> Beackbone of webpages </li>
#     <li> Essential skill for data engineering</li>
# </ul>

# %%
from IPython.display import display, HTML

html_code = """
<h1>Bangladesh</h1>
<p>Bangladesh is a South Asian country.</p>
"""

display(HTML(html_code))
# Out:
# <h1>Bangladesh</h1>
# <p>Bangladesh is a South Asian country.</p>

# %%
#Product page example


from IPython.display import display, HTML

html_code = """
<h1>Navigating a Product Page for example</h1>

<ul>
    <li>Extracting product details from an ecommerce site</li>
    <li>Example:</li>
</ul>

<div class="product">
    <h2>Product Name</h2>
    <p class="price">$19.99</p>

    <div class="description">
        <p>This product is excellent for...</p>
    </div>
</div>
"""

display(HTML(html_code))
# Out:
# <h1>Navigating a Product Page for example</h1>
#
# <ul>
#     <li>Extracting product details from an ecommerce site</li>
#     <li>Example:</li>
# </ul>
#
# <div class="product">
#     <h2>Product Name</h2>
#     <p class="price">$19.99</p>
#
#     <div class="description">
#         <p>This product is excellent for...</p>
#     </div>
# </div>

# %%
from IPython.display import display, HTML

html_code = """
<h1>HTML Basics for web Scraping</h1>

<ul>
    <li> Explored web scraping fundamentals</li>
    <li> Discussed tools, real-world applications, challenges </li>

<p>Next: BeautifulSoup basics for parsing HTML content</p>
</ul>
"""

display(HTML(html_code))
# Out:
# <h1>HTML Basics for web Scraping</h1>
#
# <ul>
#     <li> Explored web scraping fundamentals</li>
#     <li> Discussed tools, real-world applications, challenges </li>
#
# <p>Next: BeautifulSoup basics for parsing HTML content</p>
# </ul>
