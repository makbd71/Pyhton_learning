# %% [markdown]
# <a href="https://colab.research.google.com/github/makbd71/Pyhton_learning/blob/main/Dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pp = {'name':'Ronaldo', 'city':'Madrid', 'age':20}
print(pp)
# Out:
# {'name': 'Ronaldo', 'city': 'Madrid', 'age': 20}

# %%
print(pp['city'])
# Out:
# Madrid

# %%
pp.get('city')
# Out:
# 'Madrid'

# %%
keys = pp.keys()
print (pp)
# Out:
# {'name': 'Ronaldo', 'city': 'Madrid', 'age': 20}

# %%
values = pp.values()
print(values)
# Out:
# dict_values(['Ronaldo', 'Madrid', 20])

# %%
if 'name' in pp:
  print('yes')
# Out:
# yes

# %%
print(pp)
# Out:
# {'name': 'Ronaldo', 'city': 'Madrid', 'age': 20}

# %%
pa = {'name':'Messi', 'city':'Barcelona', 'age':36}
print(pa)
# Out:
# {'name': 'Messi', 'city': 'Barcelona', 'age': 36}

# %%
print(pa['name'])
# Out:
# Messi
