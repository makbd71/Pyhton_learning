# %% [markdown]
# <a href="https://colab.research.google.com/github/makbd71/Pyhton_learning/blob/main/SET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
eqp = {'Monitor', 'CPU', 'Keyboard', 'Mouse'}
print(eqp)
# Out:
# {'Keyboard', 'Monitor', 'CPU', 'Mouse'}

# %%
eqp = {'Monitor', 'CPU', 'Keyboard', 'Mouse', 'Monitor'}
print(eqp)
# Out:
# {'Keyboard', 'Monitor', 'CPU', 'Mouse'}

# %%
eqp.add ('Headphone')
print(eqp)
# Out:
# {'Monitor', 'Mouse', 'CPU', 'Keyboard', 'Headphone'}

# %%
eqp_eqp ={'Speaker'}
eqp.update(eqp_eqp)
print(eqp)
# Out:
# {'Speaker', 'Monitor', 'Mouse', 'CPU', 'Keyboard', 'Headphone'}

# %%
eqp.remove ('Headphone')
print(eqp)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1085964142.py in <cell line: 0>()
# ----> 1 eqp.remove ('Headphone')
#       2 print(eqp)
#
# KeyError: 'Headphone'
