# %% [markdown]
# <a href="https://colab.research.google.com/github/makbd71/Pyhton_learning/blob/main/Dictionaries_day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ep ={'name':'Rriddho', 'City':'Fairborn', 'age':20}
print(ep)
# Out:
# {'name': 'Rriddho', 'City': 'Fairborn', 'age': 20}

# %%
print(ep['name'])
# Out:
# Rriddho

# %%
keys= ep.keys()
print(keys)
# Out:
# dict_keys(['name', 'City', 'age'])

# %%
values= ep.values()
print (values)
# Out:
# dict_values(['Rriddho', 'Fairborn', 20])

# %%
if 'name' in ep:
  print('yes')
# Out:
# yes

# %%
ep.update({'mobile':9376088116})

# %%
print(ep)
# Out:
# {'name': 'Rriddho', 'City': 'Fairborn', 'age': 20, 'mobile': 9376088116}

# %%
for x in ep.keys():
  print(ep[x])
# Out:
# Rriddho
# Fairborn
# 20
# 9376088116

# %%
new_ep = ep
new_ep.update({'country':'USA'})
print(ep)
# Out:
# {'name': 'Rriddho', 'City': 'Fairborn', 'age': 20, 'mobile': 9376088116, 'country': 'USA'}
