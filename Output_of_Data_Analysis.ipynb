# %% [markdown]
# <a href="https://colab.research.google.com/github/makbd71/Pyhton_learning/blob/main/Output_of_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
###How to export your data analysis in CSV and Excel

# %%
merged_data.to_csv('Output.csv')

# %%
merged_data.to_csv('Output_in_excel.xlsx')
