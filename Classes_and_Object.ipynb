# %% [markdown]
# <a href="https://colab.research.google.com/github/makbd71/Pyhton_learning/blob/main/Classes_and_Object.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Social Media and online Banking are builded based on the classes and objects
#
#
# Classes
#  - Classes are blueprints
# - Consist of attributes and behaviors
#
#
# For Example if **Car is a Class **
#
# o Attributes:
#
# - Color
# - Weight
# - Model name
#
# o Behaviors:
#
# - Run
# - Reverse
# - Apply brakes
#
#
# --- Most of the software build on object orianted software design
#
#
# --- Real World Example
#
# o Banking application
#
# - "Account" is class
# - "Account for John" could be object
#
# **Classes are reuseable in Nature**

# %%
class Employee:
  def __init__(self,name,position, salary):
    self.name = name
    self.position = position
    self.salary = salary

  def display_info(self): #def display_info(self):#
      return f"{self.name} is a {self.position} earning ${self.salary} annually"

# %%
employee1 = Employee("John Doe", "Manager", 75000)
employee2 = Employee("John Smith", "Manager", 65000)

# %%
print(employee1.display_info())
print(employee2.display_info())
# Out:
# John Doe is a Manager earning $100000 annually
# John Smith is a Manager earning $65000 annually

# %%
employee1.salary = 100000
print(employee1.display_info())
# Out:
# John Doe is a Manager earning $100000 annually

# %%
class BankAccount:
    def __init__(self, account_id, balance=1000):
        self.account_id = account_id
        self.balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
        else:
            print("Invalid deposit amount")

    def get_balance(self):
        return self.balance


def display_balance(amount):
    return f"Your balance is ${amount}"


account1 = BankAccount("JJH100009876", 100)

# Get balance and display it
balance = account1.get_balance()
print(display_balance(balance))
# Out:
# Your balance is $100
