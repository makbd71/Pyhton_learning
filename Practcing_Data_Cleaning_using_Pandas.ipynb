# %% [markdown]
# <a href="https://colab.research.google.com/github/makbd71/Pyhton_learning/blob/main/Practcing_Data_Cleaning_using_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/sample_data/california_housing_test.csv')
###print(df.to_string())

# %%
new_df = df.dropna()
###print(new_df.to_string())

# %%
df.fillna(100,inplace=True) #This is filled with 100 all the null value

# %%
##print(new_df.to_string())

# %%
df["total_rooms"].fillna(100,inplace=True) #fill all then null value of unly total_room column
##print(new_df.to_string())
# Out:
# /tmp/ipykernel_2073/1621203154.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["total_rooms"].fillna(100,inplace=True) #fill all then null value of unly total_room column

# %%
df_new = df.drop_duplicates() ####drop all the duplicates
###print(df_new.to_string())

# %%
# To changeing date and time

###df["order_date"] = pd.to_datetime(df["order_date"], format = '%d%m%Y', error = 'ignore')
