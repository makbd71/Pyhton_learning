# %% [markdown]
# <a href="https://colab.research.google.com/github/makbd71/Pyhton_learning/blob/main/Data_Manipulation_%26_aggregation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Data_Manipulation & aggregation

# %%
import pandas as pd
df = pd.read_csv('/Order.csv')

print(df)
# Out:
#                            Region               Country    ItemType  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     SalesChannel OrderPriority    OrderID  UnitsSold  UnitPrice  UnitCost  \
# 0        Offline             M  686800706       8446     437.20    263.33
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#Another duplicate fuction, drop all the duplicate values

df_new = df.drop_duplicates()

# %%
avg_sale = df_new.groupby('ItemType')['UnitsSold'].mean()
print(avg_sale)
# Out:
# ItemType
# Baby Food          5018.597701
# Beverages          4999.059406
# Cereal             4908.215190
# Clothes            4845.974359
# Cosmetics          5680.960000
# Fruits             5073.214286
# Household          4818.077922
# Meat               5229.679487
# Office Supplies    4994.179775
# Personal Care      5468.091954
# Snacks             4818.829268
# Vegetables         4858.515464
# Name: UnitsSold, dtype: float64

# %%
#acg_sales by region

avg_sales_region = df_new.groupby('Region')['TotalProfit'].sum()
print(avg_sales_region)
# Out:
# Region
# Asia                                 5.079940e+07
# Australia and Oceania                3.187842e+07
# Central America and the Caribbean    4.133678e+07
# Europe                               1.067720e+08
# Middle East and North Africa         5.105699e+07
# North America                        7.708059e+06
# Sub-Saharan Africa                   1.016510e+08
# Name: TotalProfit, dtype: float64

# %%
#sum_sales by region

sum_sales_region = df_new.groupby('Region')['TotalProfit'].sum()
print(sum_sales_region)
# Out:
# Region
# Asia                                 5.079940e+07
# Australia and Oceania                3.187842e+07
# Central America and the Caribbean    4.133678e+07
# Europe                               1.067720e+08
# Middle East and North Africa         5.105699e+07
# North America                        7.708059e+06
# Sub-Saharan Africa                   1.016510e+08
# Name: TotalProfit, dtype: float64

# %%
#avg_sales by region

avg_sales_region = df_new.groupby('Region')['TotalProfit'].mean()
print(avg_sales_region)
# Out:
# Region
# Asia                                 373524.993382
# Australia and Oceania                403524.313038
# Central America and the Caribbean    417543.214242
# Europe                               399895.012921
# Middle East and North Africa         369978.212609
# North America                        405687.330000
# Sub-Saharan Africa                   387980.887252
# Name: TotalProfit, dtype: float64

# %%
df_new.aggregate(['sum','min'])
# Out:
#                                                 Region  \
# sum  Middle East and North AfricaNorth AmericaMiddl...
# min                                               Asia
#
#                                                Country  \
# sum  LibyaCanadaLibyaJapanChadArmeniaEritreaMontene...
# min                                        Afghanistan
#
#                                               ItemType  \
# sum  CosmeticsVegetablesBaby FoodCerealFruitsCereal...
# min                                          Baby Food
#
#                                           SalesChannel  \
# sum  OfflineOnlineOfflineOfflineOfflineOnlineOnline...
# min                                            Offline
#
#                                          OrderPriority       OrderID  \
# sum  MMCCHHHMHHMMCCLHHMCLCLHLHMMMHCCHLMLMHMLLCMLLLM...  549681324743
# min                                                  C     102928006
#
# ...

# %%
#information only for column UnitsSold

df_new['UnitsSold'].aggregate(['sum','min'])
# Out:
# sum    5053988
# min         13
# Name: UnitsSold, dtype: int64

# %%
#marge 2 column based one the order_ID

new_order_file = pd.read.csv('') ##need to collected and upload, which wasn't available , the new order file.
merged_data =pd.merge(new_df,new_order_file on = 'OrderID')

print(merged_data)
