# %% [markdown]
# <a href="https://colab.research.google.com/github/makbd71/Pyhton_learning/blob/main/LIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
eqp = ['Monitor','Keyborad','CPU', 'Speaker']
print(eqp)
# Out:
# ['Monitor', 'Keyborad', 'CPU', 'Speaker']

# %%
print(eqp[3])
# Out:
# Speaker

# %%
print(eqp[2])
# Out:
# CPU

# %%
eqp [3] = 'Headphone'
print(eqp)
# Out:
# ['Monitor', 'Keyborad', 'CPU', 'Headphone']

# %%
eqp.append ('Cord')
print(eqp)
# Out:
# ['Monitor', 'Keyborad', 'CPU', 'Headphone', 'Cord', 'Cord', 'Cord']

# %%
eqp.append('cable')

# %%
print(eqp)
# Out:
# ['Monitor', 'Keyborad', 'CPU', 'Headphone', 'Cord', 'Cord', 'Cord', 'cable', 'cable']

# %%
eqp.insert(1,'CPU')

# %%
print(eqp)
# Out:
# ['Monitor', 'CPU', 'CPU', 'Keyborad', 'CPU', 'Headphone', 'Cord', 'Cord', 'Cord', 'cable', 'cable']

# %%
for x in eqp:
  print(x)
# Out:
# Monitor
# CPU
# CPU
# Keyborad
# CPU
# Headphone
# Cord
# Cord
# Cord
# cable
# cable

# %%
eqp.pop(4)
# Out:
# 'Cord'

# %%
print(eqp)
# Out:
# ['Monitor', 'CPU', 'Keyborad', 'CPU', 'Cord', 'Cord', 'cable', 'cable']

# %%
eqp.insert (3,'Headphone')

# %%
print(eqp)
# Out:
# ['Monitor', 'CPU', 'Keyborad', 'Headphone', 'Headphone', 'CPU', 'Cord', 'Cord', 'cable', 'cable']

# %%
eqp.pop(3)
# Out:
# 'Headphone'

# %%
print(eqp)
# Out:
# ['Monitor', 'CPU', 'Keyborad', 'CPU', 'Cord', 'Cord', 'cable', 'cable']

# %%
eqp.remove('Cord')

# %%
print(eqp)
# Out:
# ['Monitor', 'CPU', 'Keyborad', 'cable']

# %%
for x in eqp:
  print(x)
# Out:
# Monitor
# CPU
# CPU
# Keyborad
# cable
